# %% [markdown]
# ****
# ### JSON Exercise
# Using data in file 'data/world_bank_projects.json' and the techniques demonstrated above,
#
# 1. Find the 10 countries with most projects
# 2. Find the top 10 major project themes (using column 'mjtheme_namecode')
# 3. In 2. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.

# %% [markdown]
# ****
# ### Import Packages

# %%
import pandas as pd
import json
from pandas.io.json import json_normalize

# %% [markdown]
# ****
# ### Load Data

# %%
#Here I load the data and save it as a dataframe using Pandas.
world_bank_df = pd.read_json('world_bank_projects.json')
world_bank_df.head() # This shows the first few rows of the dataframe
# Out:
#                                               sector supplementprojectflg  \
# 0  [{'Name': 'Primary education'}, {'Name': 'Seco...                    N
# 1  [{'Name': 'Public administration- Other social...                    N
# 2  [{'Name': 'Rural and Inter-Urban Roads and Hig...                    Y
# 3                [{'Name': 'Other social services'}]                    N
# 4  [{'Name': 'General industry and trade sector'}...                    N
#
#   projectfinancialtype prodline  \
# 0                  IDA       PE
# 1                OTHER       RE
# 2                  IDA       PE
# 3                OTHER       RE
# 4                  IDA       PE
#
#                                              mjtheme  idacommamt  \
# 0                                [Human development]   130000000
# 1  [Economic management, Social protection and ri...           0
# 2  [Trade and integration, Public sector governan...     6060000
# ...

# %% [markdown]
# ****
# ### 1.  10 countries with the most projects

# %%
world_bank_df.countryshortname.value_counts().head(10) #counted using countrys' short names
# Out:
# China                 19
# Indonesia             19
# Vietnam               17
# India                 16
# Yemen, Republic of    13
# Nepal                 12
# Morocco               12
# Bangladesh            12
# Africa                11
# Mozambique            11
# Name: countryshortname, dtype: int64

# %% [markdown]
# ****
# ### 2.  Top 10 major project themes

# %%
with open('world_bank_projects.json') as file: # Context Manager
    data = json.load(file)
    themes_df = json_normalize(data, 'mjtheme_namecode')    
    
major_themes_df = themes_df.name.value_counts().head(10)
major_themes_df
# Out:
# Environment and natural resources management    223
# Rural development                               202
# Human development                               197
# Public sector governance                        184
# Social protection and risk management           158
# Financial and private sector development        130
#                                                 122
# Social dev/gender/inclusion                     119
# Trade and integration                            72
# Urban development                                47
# Name: name, dtype: int64

# %% [markdown]
# ****
# ### 3.  Fill in missing values for theme names

# %%
# to have a glance at all the unique code numbers -- code #s are 1-11
themes_df.code.unique()
# Out:
# array(['8', '11', '1', '6', '5', '2', '7', '4', '10', '9', '3'],
#       dtype=object)

# %%
# create themes dict to pair up the codes with their associated theme names
themes_dict = (themes_df[themes_df.name!=''].drop_duplicates())
themes_dict = dict(zip( themes_dict .code, themes_dict .name))

# fill missing values
themes_df['clean_name']=themes_df.code.apply(lambda item: themes_dict[item])
themes_df.head(30)
# Out:
#    code                                          name  \
# 0     8                             Human development
# 1    11
# 2     1                           Economic management
# 3     6         Social protection and risk management
# 4     5                         Trade and integration
# 5     2                      Public sector governance
# 6    11  Environment and natural resources management
# 7     6         Social protection and risk management
# 8     7                   Social dev/gender/inclusion
# 9     7                   Social dev/gender/inclusion
# 10    5                         Trade and integration
# 11    4      Financial and private sector development
# 12    6         Social protection and risk management
# 13    6
# 14    2                      Public sector governance
# 15    4      Financial and private sector development
# 16   11  Environment and natural resources management
# 17    8
# 18   10                             Rural development
# 19    7
# ...
